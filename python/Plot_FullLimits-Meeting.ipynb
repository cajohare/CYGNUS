# %% [markdown]
# # Plots CYGNUS for various readout params

# %%
from numpy import *
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.rcParams['axes.linewidth'] = 2.5
fig = plt.figure(figsize=(13,12))
ax = fig.add_subplot(111)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

xmin = 0.1
xmax = 1.0e4
ymax = 1.0e-36
ymin = 1.0e-51

# Xe and F neutrino floors
nu_Xe = loadtxt("../data/WIMPLimits/SI/nufloor-Xe.txt")
nu_F = loadtxt("../data/WIMPLimits/SI/nufloor-F.txt")
plt.fill_between(nu_F[:,0], nu_F[:,1], y2=ymin,facecolor='dimgrey',alpha=0.4)
#plt.fill_between(nu_Xe[:,0], nu_Xe[:,1], y2=ymin,facecolor='dimgrey',alpha=0.4)
plt.text(0.1,2.2e-45,r"$\nu$-{\bf floor}: F",fontsize=19,rotation=22,color="k")
plt.text(0.1,0.9e-44,r"$\nu$-{\bf floor}: He",fontsize=19,rotation=22,color="k")
#plt.text(0.5,5e-48,r"{\bf Solar}-$\nu$",fontsize=25)
#plt.text(18.0,0.3e-50,r"{\bf SN}-$\nu$",fontsize=25)
#plt.text(700.0,1e-49,r"{\bf Atm}-$\nu$",fontsize=25)

nu_F = loadtxt("../data/WIMPLimits/SI/nuFloorSimple-F.txt")
#plt.plot(nu_F[0,:],nu_F[1,:],'b-')

nu_F = loadtxt("../data/WIMPLimits/SI/nuFloorSimple-Xe.txt")
#plt.plot(nu_F[0,:],nu_F[1,:],'b-')

nu_He = loadtxt("../data/WIMPLimits/SI/nuFloorSimple-He.txt")
plt.fill_between(nu_He[0,:], nu_He[1,:], y2=ymin,facecolor='dimgrey',alpha=0.4)



# Expt limits
CRESST = loadtxt("../data/WIMPLimits/SI/CRESST.txt")
plt.fill_between(CRESST[:,0], CRESST[:,1],edgecolor=None,y2=ymax,facecolor=[0.74, 0.56, 0.56])
plt.plot(CRESST[:,0], CRESST[:,1],color=[0.8, 0.25, 0.33],linewidth=3)
plt.text(0.14,2.0e-38,r"{\bf CRESST}",color=[0.8, 0.25, 0.33],fontsize=20,rotation=0)

CDMSLite = loadtxt("../data/WIMPLimits/SI/CDMSLite.txt")
plt.fill_between(CDMSLite[:,0], CDMSLite[:,1],edgecolor=None,y2=ymax,facecolor=[0.27, 0.51, 0.71])
plt.plot(CDMSLite[:,0], CDMSLite[:,1],color="blue",linewidth=3)
plt.text(0.35,1.0e-39,r"{\bf CDMSlite}",color="blue",fontsize=20,rotation=0)

DarkSide = loadtxt("../data/WIMPLimits/SI/DarkSide.txt")
plt.fill_between(DarkSide[:,0], DarkSide[:,1],edgecolor=None,y2=ymax,facecolor="forestgreen",alpha=0.5)
plt.plot(DarkSide[:,0], DarkSide[:,1],color="green",linewidth=3)
plt.text(1.5,3.0e-42,r"{\bf DarkSide}",color="green",fontsize=20,rotation=-35)

PandaX = loadtxt("../data/WIMPLimits/SI/PandaX.txt")
plt.fill_between(PandaX[:,0], PandaX[:,1],edgecolor=None,y2=ymax,facecolor="teal")
plt.plot(PandaX[:,0], PandaX[:,1],color="navy",linewidth=3)
plt.text(2300.0,5.0e-44,r"{\bf PandaX}",color="navy",fontsize=20,rotation=16)

XENON1T = loadtxt("../data/WIMPLimits/SI/XENON1T.txt")
plt.fill_between(XENON1T[:,0], XENON1T[:,1],edgecolor=None,y2=ymax,facecolor=[0.0, 0.62, 0.38])
plt.plot(XENON1T[:,0], XENON1T[:,1],color="darkgreen",linewidth=3)
plt.text(2300.0,1.5e-44,r"{\bf Xenon1T}",color="darkgreen",fontsize=20,rotation=16)

EDELWEISS = loadtxt("../data/WIMPLimits/SI/EDELWEISS.txt")
plt.plot(EDELWEISS[:,0], EDELWEISS[:,1],color=[0.67, 0.31, 0.32],linewidth=3)
plt.text(10.0,1.0e-43,r"{\bf EDELWEISS}",color=[0.67, 0.31, 0.32],fontsize=13,rotation=-20)

PICO60 = loadtxt("../data/WIMPLimits/SI/PICO60.txt")
plt.plot(PICO60[:,0], PICO60[:,1],color=[0.5, 0.0, 0.13],linewidth=3)
plt.text(2000.0,2.0e-42,r"{\bf PICO60}",color=[0.5, 0.0, 0.13],fontsize=20,rotation=18)

PICO2L = loadtxt("../data/WIMPLimits/SI/PICO2L.txt")
plt.plot(PICO2L[:,0], PICO2L[:,1],color=[0.5, 0.0, 0.13],linewidth=3)
plt.text(2000.0,2.3e-40,r"{\bf PICO2L}",color=[0.5, 0.0, 0.13],fontsize=20,rotation=18)


DAMA1 = loadtxt("../data/WIMPLimits/SI/DAMA1.txt")
DAMA2 = loadtxt("../data/WIMPLimits/SI/DAMA2.txt")
plt.fill_between(DAMA1[:,0], DAMA1[:,1],edgecolor=None,y2=ymax,facecolor=[ 0.615,  0.594,  0.825])
plt.fill_between(DAMA2[:,0], DAMA2[:,1],edgecolor=None,y2=ymax,facecolor=[ 0.615,  0.594,  0.825])
plt.plot(DAMA1[:,0], DAMA1[:,1],color=[0.32, 0.18, 0.5],linewidth=3)
plt.plot(DAMA2[:,0], DAMA2[:,1],color=[0.32, 0.18, 0.5],linewidth=3)
plt.text(22.0,1e-39,r"{\bf DAMA}",color=[0.32, 0.18, 0.5],fontsize=20)
plt.arrow(0.48, 0.79, -0.04, -0.04, transform=ax.transAxes,
          length_includes_head=True,
          head_width=0.01, head_length=0.01, overhang=0.4,
          edgecolor=[0.32, 0.18, 0.5],facecolor=[0.32, 0.18, 0.5])
plt.arrow(0.54, 0.79, 0.04, -0.08, transform=ax.transAxes,
          length_includes_head=True,
          head_width=0.01, head_length=0.01, overhang=0.4,
          edgecolor=[0.32, 0.18, 0.5],facecolor=[0.32, 0.18, 0.5])

COSINE = loadtxt("../data/WIMPLimits/SI/COSINE-100.txt")
plt.plot(COSINE[:,0], COSINE[:,1],color="gold",linewidth=3)
plt.text(1200.0,5.0e-41,r"{\bf COSINE-100}",color="gold",fontsize=20,rotation=18)


# CYGNUS
#CYGNUS1000 = loadtxt("../data/CYGNUS10k-Final.txt")
#CYGNUS1000[CYGNUS1000==0.0] = 1.0
#sig1 = minimum(CYGNUS1000[1,:],CYGNUS1000[2,:])
#sig1[sig1==1.0] = nan
#plt.plot(CYGNUS1000[0,:],sig1/2,'--',color="k",linewidth=4)



col0 = 'Crimson'
col1 = 'Navy'
col2 = 'k'


CYGNUS10k = loadtxt("../data/CYGNUS10k-1e.txt")
CYGNUS10k[CYGNUS10k==0.0] = 1.0
sig1 = minimum(CYGNUS10k[1,:],CYGNUS10k[2,:])
sig1[sig1==1.0] = nan
Nw = minimum(CYGNUS10k[3,:],CYGNUS10k[4,:])
plt.plot(CYGNUS10k[0,:],sig1,color=col0,linewidth=4,label='Single electron threshold')
plt.plot(CYGNUS10k[0,:],Nw,'--',color=col0,linewidth=1.5,label=r'$N_{\rm wimp} = 1$')

# CYGNUS10k = loadtxt("../data/CYGNUS10k-edisc.txt")
# CYGNUS10k[CYGNUS10k==0.0] = 1.0
# sig1 = minimum(CYGNUS10k[1,:],CYGNUS10k[2,:])
# sig1[sig1==1.0] = nan
# Nw = minimum(CYGNUS10k[3,:],CYGNUS10k[4,:])
# plt.plot(CYGNUS10k[0,:],sig1,color=col1,linewidth=4,label='Electron discrimination')
# plt.plot(CYGNUS10k[0,:],Nw,'--',color=col1,linewidth=1.5)


CYGNUS10k = loadtxt("../data/CYGNUS10k-predrift.txt")
CYGNUS10k[CYGNUS10k==0.0] = 1.0
sig1 = minimum(CYGNUS10k[1,:],CYGNUS10k[2,:])
sig1[sig1==1.0] = nan
Nw = minimum(CYGNUS10k[3,:],CYGNUS10k[4,:])
plt.plot(CYGNUS10k[0,:],sig1,color=col1,linewidth=4,label='Electron discrimination')
plt.plot(CYGNUS10k[0,:],Nw,'--',color=col1,linewidth=1.5,label=r'$N_{\rm wimp} = 1$')


#######


# CYGNUS10k = loadtxt("../data/CYGNUS10k-1e.txt")
# CYGNUS10k[CYGNUS10k==0.0] = 1.0
# sig1 = minimum(CYGNUS10k[1,:],CYGNUS10k[2,:])
# sig1[sig1==1.0] = nan
# Nw = minimum(CYGNUS10k[3,:],CYGNUS10k[4,:])
# plt.plot(CYGNUS10k[0,:],Nw,'-',color=col0,linewidth=4,label='Single electron (background free)')


# CYGNUS10k = loadtxt("../data/CYGNUS10k-edisc.txt")
# CYGNUS10k[CYGNUS10k==0.0] = 1.0
# sig1 = minimum(CYGNUS10k[1,:],CYGNUS10k[2,:])
# sig1[sig1==1.0] = nan
# Nw = minimum(CYGNUS10k[3,:],CYGNUS10k[4,:])
# plt.plot(CYGNUS10k[0,:],Nw,color='green',linewidth=4,label='Electron discrimination (background free)')


# CYGNUS10k = loadtxt("../data/CYGNUS10k-predrift.txt")
# CYGNUS10k[CYGNUS10k==0.0] = 1.0
# sig1 = minimum(CYGNUS10k[1,:],CYGNUS10k[2,:])
# sig1[sig1==1.0] = nan
# plt.plot(CYGNUS10k[0,:],sig1,color=col1,linewidth=4,label='Predrift directional (neutrino background)')




plt.gcf().text(0.53,0.83,r'{\bf CYGNUS-10k} $\times$ {\bf 6 yrs}',fontsize=30)

# Labels
plt.xlabel(r"WIMP mass [GeV$/c^2$]",fontsize=35)
plt.ylabel(r"SI WIMP-proton cross section [cm$^2$]",fontsize=35)

leg1 = ax.legend(fontsize=27,frameon=True,loc="lower left",framealpha=0.5,ncol=2,columnspacing=0.5)
leg1.get_frame().set_linewidth(3)
leg1.get_frame().set_edgecolor("k")

# Style
plt.yscale('log')
plt.xscale('log')
ax.set_xlim(left=xmin, right=xmax)
ax.set_ylim(bottom=ymin, top=ymax)
plt.xticks(fontsize=25)
plt.yticks(10.0**arange(log10(ymin),log10(ymax),1),fontsize=25)
ax.tick_params(which='major',direction='in',width=2,length=13,right=True,top=True,pad=7)
ax.tick_params(which='minor',direction='in',width=1,length=10,right=True,top=True)
plt.show()
fig.savefig('../plots/CYGNUS10k-SIvsMass.pdf',bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13,12))
ax = fig.add_subplot(111)

# Enhancement factor
A = 19
S_p = 0.478
J = 0.5
C_F = (4/3)*((J+1)/J)*(S_p)**2.0/A**2

xmin = 0.1
xmax = 1.0e4
ymax = 1.0e-34
ymin = 1.0e-48

# Xe and F neutrino floors
nu_Xe = loadtxt("../data/WIMPLimits/SD/nufloor-Xe.txt")
nu_F = loadtxt("../data/WIMPLimits/SD/nufloor-F.txt")
plt.fill_between(nu_F[:,0], nu_F[:,1], y2=ymin,facecolor='dimgrey',alpha=0.4)
plt.fill_between(nu_Xe[:,0], nu_Xe[:,1], y2=ymin,facecolor='dimgrey',alpha=0.4)
plt.text(0.12,3e-38,r"$\nu$-{\bf floor}: Xe",fontsize=20,rotation=22,color="k")
plt.text(0.12,1.5e-42,r"$\nu$-{\bf floor}: F",fontsize=20,rotation=25,color="k")
#plt.text(0.5,5e-45,r"{\bf Solar}-$\nu$",fontsize=25)
#plt.text(18.0,0.2e-46,r"{\bf SN}-$\nu$",fontsize=25)
#plt.text(700.0,1e-46,r"{\bf Atm}-$\nu$",fontsize=25)

# Expt limits
PICASSO = loadtxt("../data/WIMPLimits/SD/PICASSO.txt")
plt.fill_between(PICASSO[:,0], PICASSO[:,1],edgecolor=None,y2=ymax,facecolor= [0.64, 0.68, 0.82])
plt.plot(PICASSO[:,0], PICASSO[:,1],color=[0.0, 0.19, 0.33],linewidth=3)
plt.text(200.0,3.0e-37,r"{\bf PICASSO}",color=[0.0, 0.19, 0.33],fontsize=20,rotation=20)

PICO60 = loadtxt("../data/WIMPLimits/SD/PICO60.txt")
plt.fill_between(PICO60[:,0], PICO60[:,1],edgecolor=None,y2=ymax,facecolor=[0.66, 0.11, 0.03])
plt.plot(PICO60[:,0], PICO60[:,1],color=[0.5, 0.0, 0.13],linewidth=3)
plt.text(2500.0,5e-39,r"{\bf PICO60}",color=[ 0.775 ,  0.55  ,  0.6085],fontsize=20,rotation=20)

PICO2L = loadtxt("../data/WIMPLimits/SD/PICO2L.txt")
plt.plot(PICO2L[:,0], PICO2L[:,1],color=[0.5, 0.0, 0.13],linewidth=3)
plt.text(2500.0,7.5e-38,r"{\bf PICO2L}",color=[ 0.775 ,  0.55  ,  0.6085],fontsize=20,rotation=20)

COUPP = loadtxt("../data/WIMPLimits/SD/COUPP.txt")
plt.plot(COUPP[:,0], COUPP[:,1],color=[1.0, 0.55, 0.41],linewidth=3)
plt.text(200.0,1e-38,r"{\bf COUPP}",color=[1.0, 0.55, 0.41],fontsize=20,rotation=18)

KIMS = loadtxt("../data/WIMPLimits/SD/KIMS.txt")
plt.plot(KIMS[:,0], KIMS[:,1],color=[0.81, 0.44, 0.69],linewidth=3)
plt.text(3000.0,7e-37,r"{\bf KIMS}",color=[0.81, 0.44, 0.69],fontsize=20,rotation=18)

IceCube = loadtxt("../data/WIMPLimits/SD/IceCube-tt.txt")
plt.plot(IceCube[:,0], IceCube[:,1],'--',color=[0.55, 0.71, 0.0],linewidth=3)
plt.text(2000.0,5e-40,r"{\bf IceCube} $\tau\bar{\tau}$",color=[0.55, 0.71, 0.0],fontsize=20,rotation=35)

SK = loadtxt("../data/WIMPLimits/SD/SuperK-tt.txt")
plt.plot(SK[:,0], SK[:,1],'--',color=[0.24, 0.71, 0.54],linewidth=3)
plt.text(15.0,5e-41,r"{\bf SK} $\tau\bar{\tau}$",color=[0.24, 0.71, 0.54],fontsize=20,rotation=0)


CYGNUS10k = loadtxt("../data/CYGNUS10k-1e.txt")
CYGNUS10k[CYGNUS10k==0.0] = 1.0
sig1 = CYGNUS10k[1,:]
sig1[sig1==1.0] = nan
sig1 = sig1/C_F
Nw = CYGNUS10k[3,:]/C_F
plt.plot(CYGNUS10k[0,:],sig1,color=col0,linewidth=4,label='Single electron threshold')
plt.plot(CYGNUS10k[0,:],Nw,'--',color=col0,linewidth=1.5,label=r'$N_{\rm wimp} = 1$')

# CYGNUS10k = loadtxt("../data/CYGNUS10k-edisc.txt")
# CYGNUS10k[CYGNUS10k==0.0] = 1.0
# sig1 = CYGNUS10k[1,:]
# sig1[sig1==1.0] = nan
# sig1 = sig1/C_F
# Nw = CYGNUS10k[3,:]/C_F
# plt.plot(CYGNUS10k[0,:],sig1,color=col1,linewidth=4,label='Electron discrimination')
# plt.plot(CYGNUS10k[0,:],Nw,'--',color=col1,linewidth=1.5)

CYGNUS10k = loadtxt("../data/CYGNUS10k-predrift.txt")
CYGNUS10k[CYGNUS10k==0.0] = 1.0
sig1 = CYGNUS10k[1,:]
sig1[sig1==1.0] = nan
sig1 = sig1/C_F
Nw = CYGNUS10k[3,:]/C_F
plt.plot(CYGNUS10k[0,:],sig1,color=col1,linewidth=4,label='Electron discrimination')
plt.plot(CYGNUS10k[0,:],Nw,'--',color=col1,linewidth=1.5,label=r'$N_{\rm wimp} = 1$')

#leg1 = ax.legend(fontsize=25,frameon=True,loc="lower left",framealpha=0.5,ncol=2,columnspacing=0.5)



######


# CYGNUS10k = loadtxt("../data/CYGNUS10k-1e.txt")
# CYGNUS10k[CYGNUS10k==0.0] = 1.0
# sig1 = CYGNUS10k[1,:]
# sig1[sig1==1.0] = nan
# sig1 = sig1/C_F
# Nw = CYGNUS10k[3,:]/C_F
# plt.plot(CYGNUS10k[0,:],Nw,'-',color=col0,linewidth=4,label='Single electron (background free)')


# CYGNUS10k = loadtxt("../data/CYGNUS10k-edisc.txt")
# CYGNUS10k[CYGNUS10k==0.0] = 1.0
# sig1 = CYGNUS10k[1,:]
# sig1[sig1==1.0] = nan
# sig1 = sig1/C_F
# Nw = CYGNUS10k[3,:]/C_F
# plt.plot(CYGNUS10k[0,:],Nw,color='green',linewidth=4,label='Electron discrimination (background free)')


# CYGNUS10k = loadtxt("../data/CYGNUS10k-predrift.txt")
# CYGNUS10k[CYGNUS10k==0.0] = 1.0
# sig1 = CYGNUS10k[1,:]
# sig1[sig1==1.0] = nan
# sig1 = sig1/C_F
# Nw = CYGNUS10k[3,:]/C_F
# plt.plot(CYGNUS10k[0,:],sig1,color=col1,linewidth=4,label='Predrift directional (neutrino background)')








# Labels
plt.legend(loc="lower left",fontsize=23,frameon=False)
plt.xlabel(r"WIMP mass [GeV$/c^2$]",fontsize=35)
plt.ylabel(r"SD WIMP-proton cross section [cm$^2$]",fontsize=35)

leg1 = ax.legend(fontsize=27,frameon=True,loc="lower left",framealpha=0.5,ncol=2,columnspacing=0.5)
leg1.get_frame().set_linewidth(3)
leg1.get_frame().set_edgecolor("k")

plt.gcf().text(0.53,0.83,r'{\bf CYGNUS-10k} $\times$ {\bf 6 yrs}',fontsize=30,color='w')


# Style
plt.yscale('log')
plt.xscale('log')
ax.set_xlim(left=xmin, right=xmax)
ax.set_ylim(bottom=ymin, top=ymax)
plt.xticks(fontsize=25)
plt.yticks(10.0**arange(log10(ymin),log10(ymax),1),fontsize=25)
ax.tick_params(which='major',direction='in',width=2,length=13,right=True,top=True,pad=7)
ax.tick_params(which='minor',direction='in',width=1,length=10,right=True,top=True)
plt.show()
fig.savefig('../plots/CYGNUS10k_SDvsMass.pdf',bbox_inches='tight')

# %% [markdown]
# # Thresholds

# %%
plt.rcParams['axes.linewidth'] = 2.5
plt.rc('text', usetex=True)
plt.rc('font', family='serif',size=27)

fig, ax1 = plt.subplots()
fig.set_size_inches(13,12)
ax2 = ax1.twiny()  # instantiate a second axes that shares the same x-axis


xmin = 0.001
xmax = 1.0e10
ymax = 1.0e-40
ymin = 1.0e-51

C0 = loadtxt("../data/CYGNUS10k-Exposure-1e.txt")
C1 = loadtxt("../data/CYGNUS10k-Exposure-NonDirectional.txt")
C2 = loadtxt("../data/CYGNUS10k-Exposure-predrift.txt")
V = C2[0,:]
NB8_0 = C0[3,:]
NB8_1 = C1[3,:]
NB8_2 = C2[3,:]

col1 = 'k'
col0 = 'crimson'
col2 = 'navy'

#ax1.loglog(V,C0[1,:],'.-',linewidth=3,color=col0,markersize=20)
#ax1.loglog(V,C1[1,:],'.-',linewidth=3,color=col1,markersize=20)
#ax1.loglog(V,C2[1,:],'.-',linewidth=3,color=col2,markersize=20)
#ax1.fill_between(V,C0[1,:],y2=C2[1,:],color='Purple',alpha=0.3,edgecolor='none',zorder=-1)

ax1.loglog(V,C1[4,:],'.-',linewidth=3,color=col1,markersize=20,label="Predrift (no-directionality)")
#ax1.loglog(V,C0[4,:],'.-',linewidth=3,color=col0,markersize=20,label="Single electron threshold")
ax1.loglog(V,C2[4,:],'.-',linewidth=3,color=col2,markersize=20,label="Predrift (with directionality)")
ax1.fill_between(V,C1[4,:],y2=C2[4,:],color='Orange',alpha=0.3,edgecolor='none',zorder=-1)

#ax1.loglog(V,C0[7,:],'.-',linewidth=3,color=col0,markersize=20)
ax1.loglog(V,C1[7,:],'.-',linewidth=3,color=col1,markersize=20)
ax1.loglog(V,C2[7,:],'.-',linewidth=3,color=col2,markersize=20)
ax1.fill_between(V,C1[7,:],y2=C2[7,:],color='ForestGreen',alpha=0.3,edgecolor='none',zorder=-1)



# Legend
leg1 = ax1.legend(fontsize=30,frameon=True,loc="lower left",framealpha=1)
leg1.get_frame().set_linewidth(3)
leg1.get_frame().set_edgecolor("k")

# Vertical line
ax1.loglog([1e4,1e4],[ymin,ymax],'k-')
ax1.text(4000,1e-41,r'{\bf CYGNUS-10k}',fontsize=25,rotation=90)


# Labels
ax2.set_xlabel(r"Number of neutrino events",fontsize=35,labelpad=15)
ax1.set_ylabel(r"SI WIMP-proton cross section [cm$^2$]",fontsize=35)
ax1.set_xlabel(r'Volume [m$^3$]',fontsize=35)  # we already handled the x-label with ax1
ax1.set_xlim([V[0],V[-1]])
ax2.set_xlim([NB8_2[0],NB8_2[-1]])


# Arrows
#plt.gcf().text(0.3,0.3,r'$m_\chi = 1$ GeV',fontsize=35,color='Purple')
plt.gcf().text(0.62,0.55,r'$m_\chi = 10$ GeV',fontsize=35,color='Orange')
plt.gcf().text(0.64,0.17,r'$m_\chi = 100$ GeV',fontsize=35,color='ForestGreen')
#ax1.arrow(0.3, 0.3, -0.04, -0.08, transform=ax.transAxes,
#          length_includes_head=True,width=0.005,lw=1.5,
#          head_width=0.03, head_length=0.03, overhang=0.4,
#          edgecolor='k',facecolor='Purple',alpha=0.5)
ax1.arrow(0.75, 0.08, 0.04, 0.08, transform=ax.transAxes,
          length_includes_head=True,width=0.005,lw=1.5,
          head_width=0.03, head_length=0.03, overhang=0.4,
          edgecolor='k',facecolor='ForestGreen')
ax1.arrow(0.8, 0.5, -0.04, -0.08, transform=ax.transAxes,
          length_includes_head=True,width=0.005,lw=1.5,
          head_width=0.03, head_length=0.03, overhang=0.4,
          edgecolor='k',facecolor='Orange',alpha=0.5)

# Style
ax1.grid()
ax1.set_yscale('log')
ax1.set_xscale('log')
ax2.set_xscale('log')
ax1.set_ylim(bottom=ymin, top=ymax)
ax1.tick_params(which='major',direction='in',width=2,length=13,right=True,top=False,pad=10)
ax1.tick_params(which='minor',direction='in',width=1,length=10,right=True,top=False)
ax2.tick_params(which='major',direction='in',width=2,length=13,bottom=False,top=True,pad=10)
ax2.tick_params(which='minor',direction='in',width=1,length=10,bottom=False,top=True)

# # Add another axis
# pos0 = ax1.get_position()
# pos0.y1 = pos0.y1*0.86
# pos0.y0 = pos0.y1-0.00001
# ax_t0 = fig.add_axes(pos0)
# ax_t0.set_yticks([])
# ax_t0.tick_params(labelcolor=col0,top=True,bottom=False)
# ax_t0.xaxis.tick_top()
# ax_t0.set_xscale('log')
# ax_t0.set_xlim([NB8_0[0],NB8_0[-1]])
# ax_t0.spines['bottom'].set_color(col0)
# ax_t0.spines['top'].set_color(col0) 
# ax_t0.tick_params(which='major',direction='in',width=2,length=13,bottom=False,top=True,pad=10,colors=col0)

# Add another axis
# pos1 = ax1.get_position()
# pos1.y1 = pos1.y1*0.93
# pos1.y0 = pos1.y1+0.00001
# ax_t1 = fig.add_axes(pos1)
# ax_t1.set_yticks([])
# ax_t1.tick_params(labelcolor=col1,top=True,bottom=False)
# ax_t1.xaxis.tick_top()
# ax_t1.set_xscale('log')
# ax_t1.set_xlim([NB8_1[0],NB8_1[-1]])
# ax_t1.spines['bottom'].set_color(col1)
# ax_t1.spines['top'].set_color(col1) 
# ax_t1.tick_params(which='major',direction='in',width=2,length=13,bottom=False,top=True,pad=10,colors=col1)




plt.show()
fig.savefig('../plots/CYGNUS10k-indivMass.pdf',bbox_inches='tight')

# %%
ax1.get_position().height
# Out:
# 0.755

# %%
plt.rcParams['axes.linewidth'] = 2.5
plt.rc('text', usetex=True)
plt.rc('font', family='serif',size=27)

fig, ax1 = plt.subplots()
fig.set_size_inches(13,12)

xmin = 0.001
xmax = 1.0e10
ymax = 1.0e-41
ymin = 1.0e-51

C1 = loadtxt("../data/CYGNUS10k-Exposure-1e.txt")
NB8 = C1[6,:]
V = C1[0,:]
ax1.loglog(NB8,C1[4,:]*1.1,'.-',linewidth=3,color='navy',markersize=20,label="Single electron threshold")

C1 = loadtxt("../data/CYGNUS10k-Exposure-edisc.txt")
ax1.loglog(NB8,C1[4,:],'.-',linewidth=3,color='crimson',markersize=20,label="Electron discrimination")

C1 = loadtxt("../data/CYGNUS10k-Exposure-predrift.txt")
ax1.loglog(NB8,C1[4,:],'.-',linewidth=3,color='k',markersize=20,label="Predrift directional detector")

# Labels
ax1.set_xlabel(r"Number of neutrino events",fontsize=35)
ax1.set_ylabel(r"SI WIMP-proton cross section [cm$^2$]",fontsize=35)
ax1.set_xlim([NB8[0],NB8[-1]])

ax2 = ax1.twiny()  # instantiate a second axes that shares the same x-axis
ax2.set_xlabel(r'Volume [m$^3$]',fontsize=35,labelpad=15)  # we already handled the x-label with ax1
ax2.set_xlim([V[0],V[-1]])
#ax2.loglog([1e3,1e3],[ymin,ymax],'k-')
ax2.loglog([1e4,1e4],[ymin,ymax],'k-')
#ax2.loglog([1e5,1e5],[ymin,ymax],'k-')
ax2.loglog(-NB8,C1[4,:],'.-',linewidth=3,color='navy',markersize=20,label="Single electron threshold")
ax2.loglog(-NB8,C1[4,:],'.-',linewidth=3,color='crimson',markersize=20,label="Electron discrimination")
ax2.loglog(-NB8,C1[4,:],'.-',linewidth=3,color='k',markersize=20,label="Predrift directional detector")
#ax2.text(400,3e-42,r'{\bf CYGNUS-1000}',fontsize=25,rotation=90)
ax2.text(4000,3e-42,r'{\bf CYGNUS-10k}',fontsize=25,rotation=90)
#ax2.text(40000,3e-42,r'{\bf CYGNUS-100k}',fontsize=25,rotation=90)

plt.gcf().text(0.62,0.8,r'$m_\chi = 100$ GeV',fontsize=38)

# Style
ax1.grid()
#ax2.grid()
ax1.set_yscale('log')
ax1.set_xscale('log')
ax2.set_xscale('log')
ax1.set_ylim(bottom=ymin, top=ymax)
ax1.tick_params(which='major',direction='in',width=2,length=13,right=True,top=False,pad=10)
ax1.tick_params(which='minor',direction='in',width=1,length=10,right=True,top=False)
ax2.tick_params(which='major',direction='in',width=2,length=13,bottom=False,top=True,pad=10)
ax2.tick_params(which='minor',direction='in',width=1,length=10,bottom=False,top=True)
leg1 = ax2.legend(fontsize=30,frameon=True,loc="lower left",framealpha=1)
leg1.get_frame().set_linewidth(3)
leg1.get_frame().set_edgecolor("k")

plt.show()
fig.savefig('../plots/CYGNUS10k-100GeV.pdf',bbox_inches='tight')

# %%
pos1 = ax1.get_position()
print pos1
pos1.y1 *= 0.9
# Out:
# Bbox(x0=0.125, y0=0.125, x1=0.9, y1=0.88)

# %%
pos.height *= 0.9
# Out:
# 0.755
