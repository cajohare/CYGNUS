# %%
from numpy import *
from PlotFuncs import *
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import cmocean


def MakeLimitPlot_SI_alt(NuFloor=True,NuLabels=False,Annotations=True,Collected=False,\
                     xmin=0.1,xmax=1.0e4,ymax=1.0e-36,ymin=1.0e-51):
    plt.rcParams['axes.linewidth'] = 2.5
    fig = plt.figure(figsize=(15,12))
    ax = fig.add_subplot(111)
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')

    if NuFloor==True:
        # Xe and F neutrino floors
        nu_Xe = loadtxt("../data/WIMPLimits/SI/nufloor-Xe.txt")
        nu_F = loadtxt("../data/WIMPLimits/SI/nufloor-F.txt")
        plt.fill_between(nu_F[:,0], nu_F[:,1], y2=ymin,facecolor='dimgrey',alpha=0.4)
        plt.fill_between(nu_Xe[:,0], nu_Xe[:,1], y2=ymin,facecolor='dimgrey',alpha=0.4)
        #plt.text(0.14,8e-46,r"$\nu$-{\bf floor}: F",fontsize=19,rotation=22,color="k")
        #plt.text(0.11,2e-45,r"$\nu$-{\bf floor}: He",fontsize=19,rotation=22,color="k")

        if NuLabels:
            plt.text(0.5,5e-48,r"{\bf Solar}-$\nu$",fontsize=25)
            plt.text(18.0,0.3e-50,r"{\bf SN}-$\nu$",fontsize=25)
            plt.text(700.0,1e-49,r"{\bf Atm}-$\nu$",fontsize=25)

        nu_F = loadtxt("../data/WIMPLimits/SI/nuFloorSimple-F.txt")
        #plt.plot(nu_F[0,:],nu_F[1,:],'b-')

        nu_F = loadtxt("../data/WIMPLimits/SI/nuFloorSimple-Xe.txt")
        #plt.plot(nu_F[0,:],nu_F[1,:],'b-')

        nu_He = loadtxt("../data/WIMPLimits/SI/nuFloorSimple-He.txt")
        plt.fill_between(nu_He[0,:], nu_He[1,:], y2=ymin,facecolor='dimgrey',alpha=0.4)

    if Collected==False:
        if Annotations:
            plt.text(0.14,2.0e-38,r"{\bf CRESST}",color=[0.8, 0.25, 0.33],fontsize=22,rotation=0)
            plt.text(0.35,1.0e-39,r"{\bf CDMSlite}",color="blue",fontsize=22,rotation=0)
            plt.text(0.9,6e-41,r"{\bf Dark}",color="green",fontsize=22,rotation=0)
            plt.text(1.0,2e-41,r"{\bf Side}",color="green",fontsize=22,rotation=0)
            plt.text(2300.0,2.0e-44,r"{\bf PandaX}",color="navy",fontsize=22,rotation=16)
            plt.text(2300.0,4e-45,r"{\bf Xenon1T}",color="darkgreen",fontsize=22,rotation=16)
            plt.text(7.0,1.5e-44,r"{\bf EDELWEISS}",color=[0.67, 0.31, 0.32],fontsize=20,rotation=-20)
            plt.text(2000.0,5e-43,r"{\bf PICO60}",color=[0.5, 0.0, 0.13],fontsize=22,rotation=15)
            plt.text(2000.0,5.5e-41,r"{\bf PICO2L}",color=[0.5, 0.0, 0.13],fontsize=22,rotation=15)
            plt.text(22.0,1e-39,r"{\bf DAMA}",color='darkslategray',fontsize=22)
            plt.text(1200.0,0.65e-41,r"{\bf COSINE-100}",color="gold",fontsize=22,rotation=15)
            plt.arrow(0.48, 0.79, -0.04, -0.04, transform=ax.transAxes,
                  length_includes_head=True,
                  head_width=0.01, head_length=0.01, overhang=0.4,
                  edgecolor='darkslategray',facecolor='darkslategray')
            plt.arrow(0.54, 0.79, 0.04, -0.08, transform=ax.transAxes,
                  length_includes_head=True,
                  head_width=0.01, head_length=0.01, overhang=0.4,
                  edgecolor='darkslategray',facecolor='darkslategray')

        # Expt limits
        CRESST = loadtxt("../data/WIMPLimits/SI/CRESST.txt")
        plt.fill_between(CRESST[:,0], CRESST[:,1],edgecolor=None,y2=ymax,facecolor=[0.74, 0.56, 0.56])
        plt.plot(CRESST[:,0], CRESST[:,1],color='k',linewidth=5)
        plt.plot(CRESST[:,0], CRESST[:,1],color=[0.8, 0.25, 0.33],linewidth=3)

        CDMSLite = loadtxt("../data/WIMPLimits/SI/CDMSLite.txt")
        plt.fill_between(CDMSLite[:,0], CDMSLite[:,1],edgecolor=None,y2=ymax,facecolor=[0.27, 0.51, 0.71])
        plt.plot(CDMSLite[:,0], CDMSLite[:,1],color="k",linewidth=5)
        plt.plot(CDMSLite[:,0], CDMSLite[:,1],color="blue",linewidth=3)

        DarkSide = loadtxt("../data/WIMPLimits/SI/DarkSide.txt")
        plt.fill_between(DarkSide[:,0], DarkSide[:,1],edgecolor=None,y2=ymax,facecolor="forestgreen",alpha=0.5)
        plt.plot(DarkSide[:,0], DarkSide[:,1],color="k",linewidth=5)
        plt.plot(DarkSide[:,0], DarkSide[:,1],color="green",linewidth=3)

        
        PandaX = loadtxt("../data/WIMPLimits/SI/PandaX.txt")
        plt.fill_between(PandaX[:,0], PandaX[:,1],edgecolor=None,y2=ymax,facecolor="teal")
        plt.plot(PandaX[:,0], PandaX[:,1],color="k",linewidth=5)
        plt.plot(PandaX[:,0], PandaX[:,1],color="navy",linewidth=3)

        XENON1T = loadtxt("../data/WIMPLimits/SI/XENON1T.txt")
        plt.fill_between(XENON1T[:,0], XENON1T[:,1],edgecolor=None,y2=ymax,facecolor=limSI_face,alpha=0.9)
        plt.plot(XENON1T[:,0], XENON1T[:,1],color='k',linewidth=5)
        plt.plot(XENON1T[:,0], XENON1T[:,1],color=limSI_edge,linewidth=3)
        

        EDELWEISS = loadtxt("../data/WIMPLimits/SI/EDELWEISS.txt")
        plt.plot(EDELWEISS[:,0], EDELWEISS[:,1],color='k',linewidth=3)
        plt.plot(EDELWEISS[:,0], EDELWEISS[:,1],color=[0.67, 0.31, 0.32],linewidth=3)

        PICO60 = loadtxt("../data/WIMPLimits/SI/PICO60.txt")
        plt.plot(PICO60[:,0], PICO60[:,1],color='k',linewidth=5)
        plt.plot(PICO60[:,0], PICO60[:,1],color=[0.5, 0.0, 0.13],linewidth=3)

        PICO2L = loadtxt("../data/WIMPLimits/SI/PICO2L.txt")
        plt.plot(PICO2L[:,0], PICO2L[:,1],color='k',linewidth=5)
        plt.plot(PICO2L[:,0], PICO2L[:,1],color=[0.5, 0.0, 0.13],linewidth=3)


        DAMA1 = loadtxt("../data/WIMPLimits/SI/DAMA1.txt")
        DAMA2 = loadtxt("../data/WIMPLimits/SI/DAMA2.txt")
        plt.fill_between(DAMA1[:,0], DAMA1[:,1],edgecolor=None,y2=1.0e-45,facecolor='forestgreen')
        plt.fill_between(DAMA2[:,0], DAMA2[:,1],edgecolor=None,y2=1.0e-45,facecolor='forestgreen')
        plt.plot(DAMA1[:,0], DAMA1[:,1],color='k',linewidth=5)
        plt.plot(DAMA2[:,0], DAMA2[:,1],color='k',linewidth=5)
        plt.plot(DAMA1[:,0], DAMA1[:,1],color='darkslategray',linewidth=3)
        plt.plot(DAMA2[:,0], DAMA2[:,1],color='darkslategray',linewidth=3)


        COSINE = loadtxt("../data/WIMPLimits/SI/COSINE-100.txt")
        plt.plot(COSINE[:,0], COSINE[:,1],color="k",linewidth=5)
        plt.plot(COSINE[:,0], COSINE[:,1],color="gold",linewidth=3)
   
    else:
        # Expt limits
        AllLimits = loadtxt("../data/WIMPLimits/SI/AllLimits-2018.txt")
        plt.fill_between(AllLimits[:,0], AllLimits[:,1],edgecolor=None,y2=ymax,facecolor=col_alpha(limSI_face,0.5))
        plt.plot(AllLimits[:,0], AllLimits[:,1],color=limSI_edge,linewidth=3)

    
    
    
    # Labels
    plt.xlabel(r"WIMP mass [GeV$/c^2$]",fontsize=35)
    plt.ylabel(r"SI WIMP-proton cross section [cm$^2$]",fontsize=35)
    plt.yscale('log')
    plt.xscale('log')
    ax.set_xlim(left=xmin, right=xmax)
    ax.set_ylim(bottom=ymin, top=ymax)
    plt.xticks(fontsize=25)
    plt.yticks(10.0**arange(log10(ymin),log10(ymax),1),fontsize=25)
    ax.tick_params(which='major',direction='in',width=2,length=13,right=True,top=True,pad=7)
    ax.tick_params(which='minor',direction='in',width=1,length=10,right=True,top=True)

    return fig,ax

fig,ax = MakeLimitPlot_SI_alt(Annotations=True,NuFloor=False)

plt.show()
fig.savefig('/Users/ciaranohare/Work/Sydney/Presentations/images/WIMPPlot_SI.pdf',bbox_inches='tight')

# %%
fig,ax = MakeLimitPlot_SI_alt(Annotations=True,NuFloor=False)


SuperCDMS = loadtxt("../data/WIMPLimits/SI/SuperCDMS.txt",delimiter=',')
plt.plot(SuperCDMS[:,0], SuperCDMS[:,1],'--',color="lightseagreen",linewidth=5)
plt.gcf().text(0.15,0.55,r'{\bf Super-}',fontsize=30,color="lightseagreen",rotation=0,ha='left')
plt.gcf().text(0.15,0.52,r'{\bf CDMS}',fontsize=30,color="lightseagreen",rotation=0,ha='left')

LZ = loadtxt("../data/WIMPLimits/SI/LZ.txt",delimiter=',')
plt.plot(10.0**LZ[:,0], 10.0**LZ[:,1],'--',color="darkviolet",linewidth=5)
plt.gcf().text(0.83,0.38,r'{\bf LZ}',fontsize=30,color="darkviolet",rotation=15)

NEWS = loadtxt("../data/WIMPLimits/SI/NEWS-G.txt",delimiter=',')
plt.plot(NEWS[:,0], NEWS[:,1],'--',color="brown",linewidth=5)
plt.gcf().text(0.13,0.64,r'{\bf NEWS-G}',fontsize=25,color="brown",rotation=-50)

DS20 = loadtxt("../data/WIMPLimits/SI/DarkSide-20k.txt",delimiter=',')
plt.plot(DS20[:,0], DS20[:,1],'--',color="green",linewidth=5,zorder=-10)
plt.gcf().text(0.7,0.29,r'{\bf DarkSide-20k}',fontsize=30,color="green",rotation=15)


plt.show()
fig.savefig('/Users/ciaranohare/Work/Sydney/Presentations/images/WIMPPlot_SI_Future.pdf',bbox_inches='tight')

# %%
fig,ax = MakeLimitPlot_SI_alt(Annotations=True,NuFloor=False)


nu_Xe = loadtxt("../data/WIMPLimits/SI/nufloor-Xe.txt")
plt.fill_between(nu_Xe[:,0], nu_Xe[:,1], y2=1e-51,facecolor='dimgrey',alpha=0.4)
plt.plot(nu_Xe[:,0], nu_Xe[:,1],'k-',lw=5,alpha=0.5)
#plt.gcf().text(0.28,0.3,r'$\nu${\bf-floor}',fontsize=40,color="k",rotation=0)



SuperCDMS = loadtxt("../data/WIMPLimits/SI/SuperCDMS.txt",delimiter=',')
plt.plot(SuperCDMS[:,0], SuperCDMS[:,1],'--',color="lightseagreen",linewidth=5)
plt.gcf().text(0.15,0.55,r'{\bf Super-}',fontsize=30,color="lightseagreen",rotation=0,ha='left')
plt.gcf().text(0.15,0.52,r'{\bf CDMS}',fontsize=30,color="lightseagreen",rotation=0,ha='left')

LZ = loadtxt("../data/WIMPLimits/SI/LZ.txt",delimiter=',')
plt.plot(10.0**LZ[:,0], 10.0**LZ[:,1],'--',color="darkviolet",linewidth=5)
plt.gcf().text(0.83,0.38,r'{\bf LZ}',fontsize=30,color="darkviolet",rotation=15)

NEWS = loadtxt("../data/WIMPLimits/SI/NEWS-G.txt",delimiter=',')
plt.plot(NEWS[:,0], NEWS[:,1],'--',color="brown",linewidth=5)
plt.gcf().text(0.13,0.64,r'{\bf NEWS-G}',fontsize=25,color="brown",rotation=-50)

DS20 = loadtxt("../data/WIMPLimits/SI/DarkSide-20k.txt",delimiter=',')
plt.plot(DS20[:,0], DS20[:,1],'--',color="green",linewidth=5,zorder=-10)
plt.gcf().text(0.7,0.29,r'{\bf DarkSide-20k}',fontsize=30,color="green",rotation=15)


plt.show()
fig.savefig('/Users/ciaranohare/Work/Sydney/Presentations/images/WIMPPlot_SI_wFloor.pdf',bbox_inches='tight')
